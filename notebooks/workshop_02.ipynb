# %% [markdown]
# # Summary Statistics REST API workshop
#
# The following example shows how to access and parse data from the GWAS Summary Statistics database using the REST API. This demonstrates examples, but is not exhaustive. Please refer to the [documentation](https://www.ebi.ac.uk/gwas/summary-statistics/docs/) for more details.
#
# Version: `0.1`
#
# Date: `2019 June 04`
#
# REST is language-agnostic. Here we use Python, just for the purpose of demonstration.

# %%
# Importing required packages

import requests     # Manages data transfer from the GWAS Catalog REST API
import pandas as pd # Makes data handling easier
import json         # Hanling the returned data type called JSON

# %% [markdown]
# ## Endpoints
#
# Run the following to see the endpoints (associations, traits, studies, chromosomes):

# %%
# API root address:
api_url='https://www.ebi.ac.uk/gwas/summary-statistics/api'

response = requests.get(api_url)

# The returned response is a "response" object, from which we have to extract and parse the information:
decoded = response.json()

print(json.dumps(decoded, indent = 2))
# Out:
# {
#   "_links": {
#     "associations": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/associations"
#     },
#     "traits": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits"
#     },
#     "studies": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies"
#     },
#     "chromosomes": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes"
#     }
#   }
# }

# %% [markdown]
# ## Get associations for a given variant

# %%
# Accessing data for a single variant. Must be an rsID:
variant = 'rs62402518'
request_url = '{api}/associations/{variant}'.format(api=api_url, variant=variant)
response = requests.get(request_url)
decoded = response.json()

print(json.dumps(decoded, indent = 2))
# Out:
# {
#   "_embedded": {
#     "associations": {
#       "0": {
#         "p_value": 0.5701,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST002245",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.0237,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0000249"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0000249"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST002245"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST002245"
#           }
#         }
#       },
#       "1": {
#         "p_value": 1.0,
#         "code": 10,
#         "odds_ratio": 1.0,
#         "effect_allele": "T",
#         "ci_lower": 0.95,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST002318",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": null,
#         "other_allele": "C",
#         "ci_upper": 1.06,
#         "trait": [
#           "EFO_0000685"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0000685"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST002318"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST002318"
#           }
#         }
#       },
#       "2": {
#         "p_value": 0.2458,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST002920",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.0141,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0007660"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0007660"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST002920"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST002920"
#           }
#         }
#       },
#       "3": {
#         "p_value": 0.0865346,
#         "code": 10,
#         "odds_ratio": 0.9,
#         "effect_allele": "T",
#         "ci_lower": 0.7978417305357584,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003155",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.1053605156578262,
#         "other_allele": "C",
#         "ci_upper": 1.0152389490282456,
#         "trait": [
#           "EFO_0002690"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0002690"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003155"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003155"
#           }
#         }
#       },
#       "4": {
#         "p_value": 0.0865346,
#         "code": 10,
#         "odds_ratio": 0.9,
#         "effect_allele": "T",
#         "ci_lower": 0.7978417305357584,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003156",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.1053605156578262,
#         "other_allele": "C",
#         "ci_upper": 1.0152389490282456,
#         "trait": [
#           "EFO_0002690"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0002690"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003156"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003156"
#           }
#         }
#       },
#       "5": {
#         "p_value": 0.655,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003219",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": null,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0001365"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001365"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003219"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003219"
#           }
#         }
#       },
#       "6": {
#         "p_value": 0.47148900000000005,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003496",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.0070339,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0004784"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004784"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003496"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003496"
#           }
#         }
#       },
#       "7": {
#         "p_value": 0.385544,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003497",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.0084464,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0004874"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004874"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003497"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003497"
#           }
#         }
#       },
#       "8": {
#         "p_value": 0.530754,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003498",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.0108554,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0004350"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004350"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003498"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003498"
#           }
#         }
#       },
#       "9": {
#         "p_value": 0.636191,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003499",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.0046146,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0008393"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0008393"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003499"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003499"
#           }
#         }
#       },
#       "10": {
#         "p_value": 0.2628,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": 0.0581,
#         "study_accession": "GCST003724",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.0641,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0000289"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0000289"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003724"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003724"
#           }
#         }
#       },
#       "11": {
#         "p_value": 0.07289,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003769",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.018000000000000002,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0007006"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0007006"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003769"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003769"
#           }
#         }
#       },
#       "12": {
#         "p_value": 0.3656,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003770",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.006999999999999999,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0007660"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0007660"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003770"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003770"
#           }
#         }
#       },
#       "13": {
#         "p_value": 0.3129,
#         "code": 11,
#         "odds_ratio": 0.9149967975112088,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST003814",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": null,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_1001929"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_1001929"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST003814"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST003814"
#           }
#         }
#       },
#       "14": {
#         "p_value": 0.104743633194503,
#         "code": 11,
#         "odds_ratio": 0.8826125330979699,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": 0.06,
#         "study_accession": "GCST004030",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": null,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0004268"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004268"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST004030"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST004030"
#           }
#         }
#       },
#       "15": {
#         "p_value": 0.7529,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST004131",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.0089,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0003767"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0003767"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST004131"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST004131"
#           }
#         }
#       },
#       "16": {
#         "p_value": 0.4428,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST004132",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.0282,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0000384"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0000384"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST004132"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST004132"
#           }
#         }
#       },
#       "17": {
#         "p_value": 0.2318,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST004133",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.043,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0000729"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0000729"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST004133"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST004133"
#           }
#         }
#       },
#       "18": {
#         "p_value": 0.36816,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": null,
#         "study_accession": "GCST004158",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": 0.008893799999999999,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0007946"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0007946"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST004158"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST004158"
#           }
#         }
#       },
#       "19": {
#         "p_value": 0.4473,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "effect_allele_frequency": 0.9483917,
#         "study_accession": "GCST004364",
#         "variant_id": "rs62402518",
#         "base_pair_location": 21966406,
#         "chromosome": 6,
#         "beta": -0.0104416166904855,
#         "other_allele": "C",
#         "ci_upper": null,
#         "trait": [
#           "EFO_0004337"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004337"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST004364"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/6/associations/rs62402518?study_accession=GCST004364"
#           }
#         }
#       }
#     }
#   },
#   "_links": {
#     "self": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/associations/rs62402518"
#     },
#     "first": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/associations/rs62402518?size=20&start=0"
#     },
#     "next": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/associations/rs62402518?size=20&start=20"
#     }
#   }
# }

# %% [markdown]
# ### Interpreting the response
# From the returned JSON, you can see it has 20 associations each from different studies. For each association there are the values for p-value, beta, etc. and also links to the associated trait, variant, study and self (study & variant combination). It is also paginated and has `"_links"` at the bottom, showing the URLs for this page (`"self"`) the first page (`"first"`) and the next page (`"next"`). By default it shows 20 results per page, but this can be changed using the `size=` parameter, just as you see in the first and next links i.e. `?size=20`.
#
# The same 'layout' of the data applies to all the following examples.

# %% [markdown]
# ## Get a list of associations for a given trait

# %%
# Accessing data for a specific trait (EFO term):
trait = 'EFO_0004466'
request_url = '{api}/traits/{trait}/associations'.format(api=api_url, trait=trait)
response = requests.get(request_url)
decoded = response.json()

print(json.dumps(decoded, indent = 2))
# Out:
# {
#   "_embedded": {
#     "associations": {
#       "0": {
#         "p_value": 0.2267,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 132827654,
#         "effect_allele_frequency": 0.767,
#         "chromosome": 9,
#         "beta": -0.0056,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000012",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000012"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000012?study_accession=GCST000571"
#           }
#         }
#       },
#       "1": {
#         "p_value": 0.6675,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 115146454,
#         "effect_allele_frequency": 0.6950000000000001,
#         "chromosome": 9,
#         "beta": 0.0018,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000109",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000109"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000109?study_accession=GCST000571"
#           }
#         }
#       },
#       "2": {
#         "p_value": 0.6968,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 115145661,
#         "effect_allele_frequency": 0.725,
#         "chromosome": 9,
#         "beta": 0.0016,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000111",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000111"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000111?study_accession=GCST000571"
#           }
#         }
#       },
#       "3": {
#         "p_value": 0.4304,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 111032220,
#         "effect_allele_frequency": 0.31,
#         "chromosome": 9,
#         "beta": 0.0032,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000115",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000115"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000115?study_accession=GCST000571"
#           }
#         }
#       },
#       "4": {
#         "p_value": 0.6828,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 4027185,
#         "effect_allele_frequency": 0.628,
#         "chromosome": 9,
#         "beta": -0.0017,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000128",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000128"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000128?study_accession=GCST000571"
#           }
#         }
#       },
#       "5": {
#         "p_value": 0.3878,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 106925007,
#         "effect_allele_frequency": 0.885,
#         "chromosome": 9,
#         "beta": 0.006,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000152",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000152"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000152?study_accession=GCST000571"
#           }
#         }
#       },
#       "6": {
#         "p_value": 0.2516,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 100989972,
#         "effect_allele_frequency": 0.408,
#         "chromosome": 9,
#         "beta": 0.0043,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000238",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000238"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000238?study_accession=GCST000571"
#           }
#         }
#       },
#       "7": {
#         "p_value": 0.7308,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 104199704,
#         "effect_allele_frequency": 0.708,
#         "chromosome": 9,
#         "beta": -0.0013,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000378",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000378"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000378?study_accession=GCST000571"
#           }
#         }
#       },
#       "8": {
#         "p_value": 0.6028,
#         "code": 6,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 78835233,
#         "effect_allele_frequency": 0.758,
#         "chromosome": 9,
#         "beta": 0.0025,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000379",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000379"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000379?study_accession=GCST000571"
#           }
#         }
#       },
#       "9": {
#         "p_value": 0.4859,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 98496599,
#         "effect_allele_frequency": 0.5840000000000001,
#         "chromosome": 9,
#         "beta": 0.0028,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000440",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000440"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000440?study_accession=GCST000571"
#           }
#         }
#       },
#       "10": {
#         "p_value": 0.8915,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 100511487,
#         "effect_allele_frequency": 0.752,
#         "chromosome": 9,
#         "beta": -0.0007,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000477",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000477"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000477?study_accession=GCST000571"
#           }
#         }
#       },
#       "11": {
#         "p_value": 0.3705,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 122610599,
#         "effect_allele_frequency": 0.929,
#         "chromosome": 9,
#         "beta": 0.006,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000510",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000510"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000510?study_accession=GCST000571"
#           }
#         }
#       },
#       "12": {
#         "p_value": 0.2515,
#         "code": 5,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 72790943,
#         "effect_allele_frequency": 0.18600000000000003,
#         "chromosome": 9,
#         "beta": -0.0055,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000668",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000668"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000668?study_accession=GCST000571"
#           }
#         }
#       },
#       "13": {
#         "p_value": 0.3515,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 114475474,
#         "effect_allele_frequency": 0.48200000000000004,
#         "chromosome": 9,
#         "beta": 0.0036,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000709",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000709"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000709?study_accession=GCST000571"
#           }
#         }
#       },
#       "14": {
#         "p_value": 0.5288,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 114310376,
#         "effect_allele_frequency": 0.358,
#         "chromosome": 9,
#         "beta": -0.0029,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000744",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000744"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000744?study_accession=GCST000571"
#           }
#         }
#       },
#       "15": {
#         "p_value": 0.8629,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 17700648,
#         "effect_allele_frequency": 0.467,
#         "chromosome": 9,
#         "beta": -0.0007,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000770",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000770"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000770?study_accession=GCST000571"
#           }
#         }
#       },
#       "16": {
#         "p_value": 0.6504,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 84174049,
#         "effect_allele_frequency": 0.467,
#         "chromosome": 9,
#         "beta": 0.0018,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000782",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000782"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000782?study_accession=GCST000571"
#           }
#         }
#       },
#       "17": {
#         "p_value": 0.046,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 93585436,
#         "effect_allele_frequency": 0.621,
#         "chromosome": 9,
#         "beta": -0.0083,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000850",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000850"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000850?study_accession=GCST000571"
#           }
#         }
#       },
#       "18": {
#         "p_value": 0.0487,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 93585608,
#         "effect_allele_frequency": 0.389,
#         "chromosome": 9,
#         "beta": -0.0078,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000852",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000852"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000852?study_accession=GCST000571"
#           }
#         }
#       },
#       "19": {
#         "p_value": 0.2006,
#         "code": 6,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 11040895,
#         "effect_allele_frequency": 0.638,
#         "chromosome": 9,
#         "beta": 0.0051,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000893",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000893"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000893?study_accession=GCST000571"
#           }
#         }
#       }
#     }
#   },
#   "_links": {
#     "self": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466/associations"
#     },
#     "first": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466/associations?size=20&start=0"
#     },
#     "next": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466/associations?size=20&start=20"
#     }
#   }
# }

# %% [markdown]
# ## Get a list of associations for a given study

# %%
# Accessing data for a specific study. Must be a GWAS Catalog study accession ID e.g. GCST000571:
study = 'GCST000571'
request_url = '{api}/studies/{study}/associations'.format(api=api_url, study=study)
response = requests.get(request_url)
decoded = response.json()

print(json.dumps(decoded, indent = 2))
# Out:
# {
#   "_embedded": {
#     "associations": {
#       "0": {
#         "p_value": 0.2267,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 132827654,
#         "effect_allele_frequency": 0.767,
#         "chromosome": 9,
#         "beta": -0.0056,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000012",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000012"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000012?study_accession=GCST000571"
#           }
#         }
#       },
#       "1": {
#         "p_value": 0.6675,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 115146454,
#         "effect_allele_frequency": 0.6950000000000001,
#         "chromosome": 9,
#         "beta": 0.0018,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000109",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000109"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000109?study_accession=GCST000571"
#           }
#         }
#       },
#       "2": {
#         "p_value": 0.6968,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 115145661,
#         "effect_allele_frequency": 0.725,
#         "chromosome": 9,
#         "beta": 0.0016,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000111",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000111"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000111?study_accession=GCST000571"
#           }
#         }
#       },
#       "3": {
#         "p_value": 0.4304,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 111032220,
#         "effect_allele_frequency": 0.31,
#         "chromosome": 9,
#         "beta": 0.0032,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000115",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000115"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000115?study_accession=GCST000571"
#           }
#         }
#       },
#       "4": {
#         "p_value": 0.6828,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 4027185,
#         "effect_allele_frequency": 0.628,
#         "chromosome": 9,
#         "beta": -0.0017,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000128",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000128"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000128?study_accession=GCST000571"
#           }
#         }
#       },
#       "5": {
#         "p_value": 0.3878,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 106925007,
#         "effect_allele_frequency": 0.885,
#         "chromosome": 9,
#         "beta": 0.006,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000152",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000152"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000152?study_accession=GCST000571"
#           }
#         }
#       },
#       "6": {
#         "p_value": 0.2516,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 100989972,
#         "effect_allele_frequency": 0.408,
#         "chromosome": 9,
#         "beta": 0.0043,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000238",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000238"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000238?study_accession=GCST000571"
#           }
#         }
#       },
#       "7": {
#         "p_value": 0.7308,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 104199704,
#         "effect_allele_frequency": 0.708,
#         "chromosome": 9,
#         "beta": -0.0013,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000378",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000378"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000378?study_accession=GCST000571"
#           }
#         }
#       },
#       "8": {
#         "p_value": 0.6028,
#         "code": 6,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 78835233,
#         "effect_allele_frequency": 0.758,
#         "chromosome": 9,
#         "beta": 0.0025,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000379",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000379"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000379?study_accession=GCST000571"
#           }
#         }
#       },
#       "9": {
#         "p_value": 0.4859,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "C",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 98496599,
#         "effect_allele_frequency": 0.5840000000000001,
#         "chromosome": 9,
#         "beta": 0.0028,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000440",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000440"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000440?study_accession=GCST000571"
#           }
#         }
#       },
#       "10": {
#         "p_value": 0.8915,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 100511487,
#         "effect_allele_frequency": 0.752,
#         "chromosome": 9,
#         "beta": -0.0007,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000477",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000477"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000477?study_accession=GCST000571"
#           }
#         }
#       },
#       "11": {
#         "p_value": 0.3705,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 122610599,
#         "effect_allele_frequency": 0.929,
#         "chromosome": 9,
#         "beta": 0.006,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000510",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000510"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000510?study_accession=GCST000571"
#           }
#         }
#       },
#       "12": {
#         "p_value": 0.2515,
#         "code": 5,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 72790943,
#         "effect_allele_frequency": 0.18600000000000003,
#         "chromosome": 9,
#         "beta": -0.0055,
#         "other_allele": "T",
#         "ci_upper": null,
#         "variant_id": "rs1000668",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000668"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000668?study_accession=GCST000571"
#           }
#         }
#       },
#       "13": {
#         "p_value": 0.3515,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "T",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 114475474,
#         "effect_allele_frequency": 0.48200000000000004,
#         "chromosome": 9,
#         "beta": 0.0036,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000709",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000709"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000709?study_accession=GCST000571"
#           }
#         }
#       },
#       "14": {
#         "p_value": 0.5288,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 114310376,
#         "effect_allele_frequency": 0.358,
#         "chromosome": 9,
#         "beta": -0.0029,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000744",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000744"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000744?study_accession=GCST000571"
#           }
#         }
#       },
#       "15": {
#         "p_value": 0.8629,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 17700648,
#         "effect_allele_frequency": 0.467,
#         "chromosome": 9,
#         "beta": -0.0007,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000770",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000770"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000770?study_accession=GCST000571"
#           }
#         }
#       },
#       "16": {
#         "p_value": 0.6504,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 84174049,
#         "effect_allele_frequency": 0.467,
#         "chromosome": 9,
#         "beta": 0.0018,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000782",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000782"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000782?study_accession=GCST000571"
#           }
#         }
#       },
#       "17": {
#         "p_value": 0.046,
#         "code": 11,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 93585436,
#         "effect_allele_frequency": 0.621,
#         "chromosome": 9,
#         "beta": -0.0083,
#         "other_allele": "A",
#         "ci_upper": null,
#         "variant_id": "rs1000850",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000850"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000850?study_accession=GCST000571"
#           }
#         }
#       },
#       "18": {
#         "p_value": 0.0487,
#         "code": 10,
#         "odds_ratio": null,
#         "effect_allele": "A",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 93585608,
#         "effect_allele_frequency": 0.389,
#         "chromosome": 9,
#         "beta": -0.0078,
#         "other_allele": "G",
#         "ci_upper": null,
#         "variant_id": "rs1000852",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000852"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000852?study_accession=GCST000571"
#           }
#         }
#       },
#       "19": {
#         "p_value": 0.2006,
#         "code": 6,
#         "odds_ratio": null,
#         "effect_allele": "G",
#         "ci_lower": null,
#         "study_accession": "GCST000571",
#         "base_pair_location": 11040895,
#         "effect_allele_frequency": 0.638,
#         "chromosome": 9,
#         "beta": 0.0051,
#         "other_allele": "C",
#         "ci_upper": null,
#         "variant_id": "rs1000893",
#         "trait": [
#           "EFO_0004466"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0004466"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000893"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1000893?study_accession=GCST000571"
#           }
#         }
#       }
#     }
#   },
#   "_links": {
#     "self": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571/associations"
#     },
#     "first": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571/associations?size=20&start=0"
#     },
#     "next": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000571/associations?size=20&start=20"
#     }
#   }
# }

# %% [markdown]
# ## Get a list of associations within a genomic region

# %%
# Accessing data for a specific genomic region (e.g. chr9:132000000-133000000):
chromosome = 9
bp_lower = 132000000
bp_upper = 133000000
request_url = '{api}/chromosomes/{chrom}/associations?bp_lower={low}&bp_upper={high}'.format(api=api_url, 
                                                                                             chrom=chromosome, 
                                                                                             low=bp_lower,
                                                                                             high=bp_upper)
response = requests.get(request_url)
decoded = response.json()

print(json.dumps(decoded, indent = 2))
# Out:
# {
#   "_embedded": {
#     "associations": {
#       "0": {
#         "p_value": 0.7737712805217729,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132011450,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs7040224",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7040224"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7040224?study_accession=GCST000392"
#           }
#         }
#       },
#       "1": {
#         "p_value": 0.891531732402952,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132015043,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs4363310",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4363310"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4363310?study_accession=GCST000392"
#           }
#         }
#       },
#       "2": {
#         "p_value": 0.82089165339188,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132021500,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs9411334",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411334"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411334?study_accession=GCST000392"
#           }
#         }
#       },
#       "3": {
#         "p_value": 0.7561297884041221,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132024356,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs11243598",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs11243598"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs11243598?study_accession=GCST000392"
#           }
#         }
#       },
#       "4": {
#         "p_value": 0.8222717765291421,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132031876,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs7026534",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7026534"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7026534?study_accession=GCST000392"
#           }
#         }
#       },
#       "5": {
#         "p_value": 0.400987966655359,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132036880,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs4360408",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4360408"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4360408?study_accession=GCST000392"
#           }
#         }
#       },
#       "6": {
#         "p_value": 0.797031313106004,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132037227,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs7467576",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7467576"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7467576?study_accession=GCST000392"
#           }
#         }
#       },
#       "7": {
#         "p_value": 0.79593237020196,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132037291,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs7467596",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7467596"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7467596?study_accession=GCST000392"
#           }
#         }
#       },
#       "8": {
#         "p_value": 0.21205090688605,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132037991,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs10512416",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10512416"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10512416?study_accession=GCST000392"
#           }
#         }
#       },
#       "9": {
#         "p_value": 0.7723515044006001,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132038998,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs9328536",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9328536"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9328536?study_accession=GCST000392"
#           }
#         }
#       },
#       "10": {
#         "p_value": 0.889941667313076,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132046098,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs9411433",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411433"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411433?study_accession=GCST000392"
#           }
#         }
#       },
#       "11": {
#         "p_value": 0.820590070551175,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132051571,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs4617289",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4617289"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4617289?study_accession=GCST000392"
#           }
#         }
#       },
#       "12": {
#         "p_value": 0.80633596207411,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132053735,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs4292819",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4292819"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4292819?study_accession=GCST000392"
#           }
#         }
#       },
#       "13": {
#         "p_value": 0.429581221658784,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132059599,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs4526483",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4526483"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4526483?study_accession=GCST000392"
#           }
#         }
#       },
#       "14": {
#         "p_value": 0.830475426080364,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132068602,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs9411340",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411340"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411340?study_accession=GCST000392"
#           }
#         }
#       },
#       "15": {
#         "p_value": 0.84200239990677,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132069041,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs7851262",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7851262"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7851262?study_accession=GCST000392"
#           }
#         }
#       },
#       "16": {
#         "p_value": 0.9022017626256592,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132071418,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs9411438",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411438"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs9411438?study_accession=GCST000392"
#           }
#         }
#       },
#       "17": {
#         "p_value": 0.3158310901724149,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132086447,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs4962112",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4962112"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4962112?study_accession=GCST000392"
#           }
#         }
#       },
#       "18": {
#         "p_value": 0.372668655492222,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132090256,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs7038996",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7038996"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7038996?study_accession=GCST000392"
#           }
#         }
#       },
#       "19": {
#         "p_value": 0.0395114975117606,
#         "code": 14,
#         "odds_ratio": null,
#         "effect_allele": null,
#         "ci_lower": null,
#         "study_accession": "GCST000392",
#         "base_pair_location": 132098055,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": null,
#         "ci_upper": null,
#         "variant_id": "rs11787577",
#         "trait": [
#           "EFO_0001359"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001359"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs11787577"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST000392"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs11787577?study_accession=GCST000392"
#           }
#         }
#       }
#     }
#   },
#   "_links": {
#     "self": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations?bp_upper=133000000&bp_lower=132000000"
#     },
#     "first": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations?bp_upper=133000000&size=20&start=0&bp_lower=132000000"
#     },
#     "next": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations?bp_upper=133000000&size=20&start=20&bp_lower=132000000"
#     }
#   }
# }

# %% [markdown]
# ## Get a list of associations below a p-value threshold
#
# You may want to filter the associations to only those that are below a p-value threshold e.g. for a given trait such as diabetes type II (EFO_0001360) you want all the associations below p-value 1.0e-5:

# %%
# Accessing data for a specific trait (EFO term) below a p-value threshold:
trait = 'EFO_0001360'
pval_upper = 1.0e-5 # can be any valid float e.g. 0.00001
request_url = '{api}/traits/{trait}/associations?p_upper={high}'.format(api=api_url, 
                                                                        trait=trait,
                                                                        high=pval_upper)
response = requests.get(request_url)
decoded = response.json()

print(json.dumps(decoded, indent = 2))
# Out:
# {
#   "_embedded": {
#     "associations": {
#       "0": {
#         "p_value": 1.3e-06,
#         "code": 11,
#         "odds_ratio": 0.9345794392523364,
#         "effect_allele": "T",
#         "ci_lower": 0.9090909090909092,
#         "study_accession": "GCST005047",
#         "base_pair_location": 4283137,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "G",
#         "ci_upper": 0.9615384615384616,
#         "variant_id": "rs1574285",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1574285"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1574285?study_accession=GCST005047"
#           }
#         }
#       },
#       "1": {
#         "p_value": 5.400000000000001e-06,
#         "code": 11,
#         "odds_ratio": 0.9433962264150942,
#         "effect_allele": "G",
#         "ci_lower": 0.9259259259259258,
#         "study_accession": "GCST005047",
#         "base_pair_location": 4287466,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "A",
#         "ci_upper": 0.9708737864077671,
#         "variant_id": "rs7041847",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7041847"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7041847?study_accession=GCST005047"
#           }
#         }
#       },
#       "2": {
#         "p_value": 6.3e-07,
#         "code": 10,
#         "odds_ratio": 1.06,
#         "effect_allele": "A",
#         "ci_lower": 1.04,
#         "study_accession": "GCST005047",
#         "base_pair_location": 4289050,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "C",
#         "ci_upper": 1.09,
#         "variant_id": "rs7034200",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7034200"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7034200?study_accession=GCST005047"
#           }
#         }
#       },
#       "3": {
#         "p_value": 3.4e-08,
#         "code": 5,
#         "odds_ratio": 1.07,
#         "effect_allele": "C",
#         "ci_lower": 1.05,
#         "study_accession": "GCST005047",
#         "base_pair_location": 4290085,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "G",
#         "ci_upper": 1.1,
#         "variant_id": "rs4237150",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4237150"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4237150?study_accession=GCST005047"
#           }
#         }
#       },
#       "4": {
#         "p_value": 1.8e-07,
#         "code": 5,
#         "odds_ratio": 1.07,
#         "effect_allele": "T",
#         "ci_lower": 1.04,
#         "study_accession": "GCST005047",
#         "base_pair_location": 4290823,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "A",
#         "ci_upper": 1.1,
#         "variant_id": "rs6476839",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs6476839"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs6476839?study_accession=GCST005047"
#           }
#         }
#       },
#       "5": {
#         "p_value": 5.1e-07,
#         "code": 10,
#         "odds_ratio": 1.07,
#         "effect_allele": "A",
#         "ci_lower": 1.04,
#         "study_accession": "GCST005047",
#         "base_pair_location": 4292083,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "G",
#         "ci_upper": 1.1,
#         "variant_id": "rs10758593",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10758593"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10758593?study_accession=GCST005047"
#           }
#         }
#       },
#       "6": {
#         "p_value": 1.2e-09,
#         "code": 6,
#         "odds_ratio": 0.8264462809917356,
#         "effect_allele": "G",
#         "ci_lower": 0.7751937984496123,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22128181,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "C",
#         "ci_upper": 0.8771929824561404,
#         "variant_id": "rs12379111",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs12379111"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs12379111?study_accession=GCST005047"
#           }
#         }
#       },
#       "7": {
#         "p_value": 5e-08,
#         "code": 11,
#         "odds_ratio": 0.9009009009009008,
#         "effect_allele": "A",
#         "ci_lower": 0.8695652173913044,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22128601,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "G",
#         "ci_upper": 0.9345794392523364,
#         "variant_id": "rs10811658",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10811658"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10811658?study_accession=GCST005047"
#           }
#         }
#       },
#       "8": {
#         "p_value": 1.7e-24,
#         "code": 11,
#         "odds_ratio": 0.8333333333333334,
#         "effect_allele": "T",
#         "ci_lower": 0.8064516129032259,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22129580,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "C",
#         "ci_upper": 0.8620689655172414,
#         "variant_id": "rs7020996",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7020996"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs7020996?study_accession=GCST005047"
#           }
#         }
#       },
#       "9": {
#         "p_value": 4.2e-19,
#         "code": 11,
#         "odds_ratio": 0.8474576271186441,
#         "effect_allele": "G",
#         "ci_lower": 0.8130081300813008,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22130066,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "A",
#         "ci_upper": 0.8771929824561404,
#         "variant_id": "rs10965243",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10965243"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10965243?study_accession=GCST005047"
#           }
#         }
#       },
#       "10": {
#         "p_value": 6.1e-13,
#         "code": 11,
#         "odds_ratio": 0.8620689655172414,
#         "effect_allele": "A",
#         "ci_lower": 0.8333333333333334,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22130516,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "G",
#         "ci_upper": 0.9009009009009008,
#         "variant_id": "rs10965245",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10965245"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10965245?study_accession=GCST005047"
#           }
#         }
#       },
#       "11": {
#         "p_value": 4.400000000000001e-34,
#         "code": 11,
#         "odds_ratio": 0.8333333333333334,
#         "effect_allele": "G",
#         "ci_lower": 0.8064516129032259,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22132077,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "A",
#         "ci_upper": 0.8547008547008548,
#         "variant_id": "rs2383208",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs2383208"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs2383208?study_accession=GCST005047"
#           }
#         }
#       },
#       "12": {
#         "p_value": 9.999999999999999e-23,
#         "code": 11,
#         "odds_ratio": 0.8264462809917356,
#         "effect_allele": "A",
#         "ci_lower": 0.7936507936507936,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22133285,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "G",
#         "ci_upper": 0.8620689655172414,
#         "variant_id": "rs10965250",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10965250"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10965250?study_accession=GCST005047"
#           }
#         }
#       },
#       "13": {
#         "p_value": 1.1e-27,
#         "code": 11,
#         "odds_ratio": 0.8264462809917356,
#         "effect_allele": "C",
#         "ci_lower": 0.8,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22134095,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "T",
#         "ci_upper": 0.8547008547008548,
#         "variant_id": "rs10811661",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10811661"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs10811661?study_accession=GCST005047"
#           }
#         }
#       },
#       "14": {
#         "p_value": 5.9e-15,
#         "code": 6,
#         "odds_ratio": 0.8264462809917356,
#         "effect_allele": "T",
#         "ci_lower": 0.7936507936507936,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22136490,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "A",
#         "ci_upper": 0.8695652173913044,
#         "variant_id": "rs1333051",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1333051"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1333051?study_accession=GCST005047"
#           }
#         }
#       },
#       "15": {
#         "p_value": 4.5e-06,
#         "code": 6,
#         "odds_ratio": 0.8403361344537815,
#         "effect_allele": "A",
#         "ci_lower": 0.78125,
#         "study_accession": "GCST005047",
#         "base_pair_location": 22301093,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "T",
#         "ci_upper": 0.9090909090909092,
#         "variant_id": "rs1575972",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1575972"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs1575972?study_accession=GCST005047"
#           }
#         }
#       },
#       "16": {
#         "p_value": 1.1e-09,
#         "code": 11,
#         "odds_ratio": 0.8547008547008548,
#         "effect_allele": "G",
#         "ci_lower": 0.8130081300813008,
#         "study_accession": "GCST005047",
#         "base_pair_location": 79266915,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "A",
#         "ci_upper": 0.9009009009009008,
#         "variant_id": "rs13293121",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs13293121"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs13293121?study_accession=GCST005047"
#           }
#         }
#       },
#       "17": {
#         "p_value": 3.5e-09,
#         "code": 11,
#         "odds_ratio": 0.8620689655172414,
#         "effect_allele": "A",
#         "ci_lower": 0.819672131147541,
#         "study_accession": "GCST005047",
#         "base_pair_location": 79267424,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "G",
#         "ci_upper": 0.9090909090909092,
#         "variant_id": "rs4295736",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4295736"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs4295736?study_accession=GCST005047"
#           }
#         }
#       },
#       "18": {
#         "p_value": 5.3e-08,
#         "code": 11,
#         "odds_ratio": 0.8849557522123894,
#         "effect_allele": "C",
#         "ci_lower": 0.8474576271186441,
#         "study_accession": "GCST005047",
#         "base_pair_location": 79282450,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "T",
#         "ci_upper": 0.9259259259259258,
#         "variant_id": "rs17198915",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs17198915"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs17198915?study_accession=GCST005047"
#           }
#         }
#       },
#       "19": {
#         "p_value": 1e-07,
#         "code": 11,
#         "odds_ratio": 0.8849557522123894,
#         "effect_allele": "G",
#         "ci_lower": 0.8474576271186441,
#         "study_accession": "GCST005047",
#         "base_pair_location": 79284065,
#         "effect_allele_frequency": null,
#         "chromosome": 9,
#         "beta": null,
#         "other_allele": "A",
#         "ci_upper": 0.9259259259259258,
#         "variant_id": "rs17791483",
#         "trait": [
#           "EFO_0001360"
#         ],
#         "_links": {
#           "trait": [
#             {
#               "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360"
#             }
#           ],
#           "variant": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs17791483"
#           },
#           "study": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/studies/GCST005047"
#           },
#           "self": {
#             "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/chromosomes/9/associations/rs17791483?study_accession=GCST005047"
#           }
#         }
#       }
#     }
#   },
#   "_links": {
#     "self": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360/associations?p_upper=1e-05"
#     },
#     "first": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360/associations?size=20&start=0&p_upper=1e-05"
#     },
#     "next": {
#       "href": "https://www.ebi.ac.uk/gwas/summary-statistics/api/traits/EFO_0001360/associations?size=20&start=20&p_upper=1e-05"
#     }
#   }
# }

# %% [markdown]
# Let's write the above so that it returns the response in a pandas dataframe

# %%
# return a pandas dataframe of results for the above example:

extracted_data = []
size = 10

trait = 'EFO_0001360'
pval_upper = 1.0e-5 # can be any valid float e.g. 0.00001
request_url = '{api}/traits/{trait}/associations?p_upper={high}&size={size}'.format(api=api_url, 
                                                                                    trait=trait,
                                                                                    high=pval_upper,
                                                                                    size=size)
response = requests.get(request_url)
decoded = response.json()

for i in range(0, size):
    association = decoded['_embedded']['associations'][str(i)]

    pval = association['p_value']
    bp = association['base_pair_location']
    chrom = association['chromosome']
    ea = association['effect_allele']
    oa = association['other_allele']
    beta = association['beta']
    odds = association['odds_ratio']
    
    extracted_data.append({'trait': trait,
                           'pvalue': pval,
                           'position': bp,
                           'chromosome': chrom,
                           'effect_allele': ea,
                           'other_allele': oa,
                           'beta': beta,
                           'odds_ratio': odds
                          })


table = pd.DataFrame.from_dict(extracted_data)
table
# Out:
#    beta  chromosome effect_allele  odds_ratio other_allele  position  \
# 0  None           9             T    0.934579            G   4283137
# 1  None           9             G    0.943396            A   4287466
# 2  None           9             A    1.060000            C   4289050
# 3  None           9             C    1.070000            G   4290085
# 4  None           9             T    1.070000            A   4290823
# 5  None           9             A    1.070000            G   4292083
# 6  None           9             G    0.826446            C  22128181
# 7  None           9             A    0.900901            G  22128601
# 8  None           9             T    0.833333            C  22129580
# 9  None           9             G    0.847458            A  22130066
#
#          pvalue        trait
# 0  1.300000e-06  EFO_0001360
# 1  5.400000e-06  EFO_0001360
# 2  6.300000e-07  EFO_0001360
# 3  3.400000e-08  EFO_0001360
# 4  1.800000e-07  EFO_0001360
# 5  5.100000e-07  EFO_0001360
# 6  1.200000e-09  EFO_0001360
# 7  5.000000e-08  EFO_0001360
# 8  1.700000e-24  EFO_0001360
# 9  4.200000e-19  EFO_0001360
